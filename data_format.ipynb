# %%
import pandas as pd

# %%
# read the file /workspace/2404170001/pyserini_data/bm25_run.txt and check 10 top lines only
with open('/workspace/2404170001/pyserini_data/bm25_run.txt', 'r') as f:
    for i in range(10):
        print(f.readline().strip())
# Out:
# 2 Q0 1001873 1 12.873300 Anserini
# 2 Q0 1782337 2 12.682300 Anserini
# 2 Q0 4339075 3 12.543400 Anserini
# 2 Q0 4339068 4 12.155900 Anserini
# 2 Q0 7496507 5 12.146700 Anserini
# 2 Q0 7496506 6 12.119400 Anserini
# 2 Q0 6920058 7 12.107400 Anserini
# 2 Q0 6285817 8 12.084500 Anserini
# 2 Q0 4339072 9 12.031000 Anserini
# 2 Q0 7496505 10 11.900800 Anserini

# %%
# read the file /home/jiit_2404170001/Downloads/job1/gpu-dev-container/estop/validation.tsv
pd.read_csv('/workspace/2404170001/estop/validation.tsv', sep='\t', nrows=10)
# Out:
#    255  7629888  +what is centure  \
# 0  255  5337494  +what is centure
# 1  255  3092927  +what is centure
# 2  255  2332343  +what is centure
# 3  255  8672868  +what is centure
# 4  255  7942983  +what is centure
# 5  255  3534898  +what is centure
# 6  255  8740723  +what is centure
# 7  255  2624439  +what is centure
# 8  255  8080899  +what is centure
# 9  255  2280509  +what is centure
#
#   What do the centure clay pot and the seven cones represent on a pianta? Throughout the history of the pinata, it usually didn't have a meaning. But not for a few long years later, was the pinatas main points religiously named.
# 0  Why is Japan considered an âearly late devel...
# 1  No. Nineveh was an ancient city in Assyria, Me...
# 2  Nancy Morejon (MorejÃ³n, havana). 1944 with a ...
# 3  The Flying Girl has 13 ratings and 6 reviews. ...
# 4  Saint Estelle was born and resided in the regi...
# 5  Making the world better, one answer at a time....
# ...

# %%
# read the tsv file using pandas
pa = "/workspace/2404170001/clustering_output1/cluster-assignment-ids.tsv"
df = pd.read_csv(pa, sep="\t")
df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[6], line 3
#       1 # read the tsv file using pandas
#       2 pa = "/workspace/2404170001/clustering_output1/cluster-assignment-ids.tsv"
# ----> 3 df = pd.read_csv(pa, sep="\t")
#       4 df
#
# ...
