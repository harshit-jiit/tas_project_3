# %%
import pandas as pd

# %%
p = "/home/jiit_2404170001/Downloads/job1/gpu-dev-container/validation_test_split/queries_test.tsv"

# %%
d = pd.read_csv(p, sep="\t", header=None)

# %%
d.head()
# Out:
#          0                                          1
# 0  1000000          where does real insulin come from
# 1  1000003                     where does parrot live
# 2  1000004             where does name nora come from
# 3  1000006  where does most of the iron ore come from
# 4  1000012                        where is weston, fl

# %%
d.columns= ["queruy_id", "query"]

# %%
d.head()
# Out:
#    queruy_id                                      query
# 0    1000000          where does real insulin come from
# 1    1000003                     where does parrot live
# 2    1000004             where does name nora come from
# 3    1000006  where does most of the iron ore come from
# 4    1000012                        where is weston, fl

# %%
d["queruy_id"].nunique()
# Out:
# 52378

# %%
ap = "/home/jiit_2404170001/Downloads/job1/gpu-dev-container/validation_test_split/queries_validation.tsv"

# %%
ad = pd.read_csv(ap, sep="\t", header=None)

# %%
ad.columns= ["queruy_id", "query"]

# %%
ad["queruy_id"].nunique()
# Out:
# 3200

# %%
add = "/home/jiit_2404170001/Downloads/job1/gpu-dev-container/inputs/queries.dev.small.tsv"

# %%
pdd = pd.read_csv(add, sep="\t", header=None)

# %%
pdd.columns = ["queruy_id","query"]

# %%
pdd["queruy_id"].nunique()
# Out:
# 55578

# %%
qv = "/home/jiit_2404170001/Downloads/job1/gpu-dev-container/validation_test_split/validation.tsv"
qvd = pd.read_csv(qv, sep="\t", header=None)
qvd.head()
# Out:
#         0        1                                          2  \
# 0  598962  1782646                what colors make lime green
# 1  846223  3010593      what is the second trimesters divided
# 2  340006  6651435  how soon together for epidural injections
# 3  992417  7187154                    whitney wolfe net worth
# 4  998899  3086809                           definition eaves
#
#                                                    3
# 0  Lime green and golden yellow are two of the mo...
# 1  From 12 weeks to 27 weeks the fetus continues ...
# 2  Epidural steroid injections may be repeated as...
# 3  John Salley Net Worth; Rochelle Aytes Net Wort...
# 4  Eaves are the horizontal section of a roof tha...

# %%
qvd.columns = ["query_id", "query", "passage_id", "passage"]

# %%
qvd
# Out:
#         query_id    query                                         passage_id  \
# 0         598962  1782646                        what colors make lime green
# 1         846223  3010593              what is the second trimesters divided
# 2         340006  6651435          how soon together for epidural injections
# 3         992417  7187154                            whitney wolfe net worth
# 4         998899  3086809                                   definition eaves
# ...          ...      ...                                                ...
# 321160    178514  7999994                    effects of alcohol on your body
# 321161   1093995  2087027                                is silicon an alloy
# 321162   1083146  7140161                           what does racetrack mean
# 321163   1102407  7209712  why do auroras form, where do they form, and why?
# 321164   1102407  7209713  why do auroras form, where do they form, and why?
#
# ...

# %%
qt = "/home/jiit_2404170001/Downloads/job1/gpu-dev-container/validation_test_split/test.tsv"
qvt = pd.read_csv(qt, sep="\t", header=None)
qvt.head()
# Out:
#          0        1                                             2  \
# 0  1091630  2079693                           phone number of pnc
# 1    43677  8595669  average salary vice president of real estate
# 2  1090181  3810789                               synonyms enable
# 3   529524  1011929                            types of rejection
# 4  1070340  5233219                        what is a mirror file?
#
#                                                    3
# 0  bank city state routing number; pnc bank. nati...
# 1  The average pay for a Vice President (VP), Rea...
# 2  Synonym.com is the web's best resource for Eng...
# 3  Type I error. When the null hypothesis is true...
# 4  You may not know what a gesso mirror is, but i...

# %%
qvt.columns = ["query_id", "query", "passage_id", "passage"]

# %%
qvt
# Out:
#          query_id    query                                    passage_id  \
# 0         1091630  2079693                           phone number of pnc
# 1           43677  8595669  average salary vice president of real estate
# 2         1090181  3810789                               synonyms enable
# 3          529524  1011929                            types of rejection
# 4         1070340  5233219                        what is a mirror file?
# ...           ...      ...                                           ...
# 5250608    935672  7969153       when are liquidated damages appropriate
# 5250609    173168  7997682                  does thrush hurt your tongue
# 5250610   1087539  7101236                           what are iron sites
# 5250611   1084600  7126779          what do you mean by meeting minutes?
# 5250612   1036722  7206869                     what is the meaning anal?
#
#                                                    passage
# ...

# %%
qvt["query_id"].value_counts()
# Out:
# query_id
# 593523     104
# 206007     104
# 375184     104
# 883689     104
# 458013     104
#           ...
# 1088872     19
# 1090291     16
# 1088888     15
# 1025021     13
# 1088970      7
# Name: count, Length: 52378, dtype: int64
